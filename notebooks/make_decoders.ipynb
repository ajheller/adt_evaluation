# %%
# !git config --global user.email "ajheller@gmail.com"; git config --global user.name "Aaron Heller"

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !rm -rf adt_evaluation/

# %%
# !git clone https://bitbucket.org/ambidecodertoolbox/adt_evaluation.git
# Out:
# Cloning into 'adt_evaluation'...
# remote: Counting objects: 682, done.
# remote: Compressing objects: 100% (677/677), done.
# remote: Total 682 (delta 427), reused 0 (delta 0)
# Receiving objects: 100% (682/682), 344.66 KiB | 2.18 MiB/s, done.
# Resolving deltas: 100% (427/427), done.

# %%
# !cd adt_evaluation/; git pull
# Out:
# Already up to date.

# %%
# %cd /content/drive/MyDrive/adt_evaluation/

TF_CPP_MIN_LOG_LEVEL=0
import optimize_decoder_matrix as odm

M_opt, debug = odm.stage_test(3)
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/adt_evaluation/'
# /Users/heller/Documents/adt_evaluation/notebooks
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c1f3875c85bd> in <module>
#       1 get_ipython().run_line_magic('cd', '/content/drive/MyDrive/adt_evaluation/')
#       2 TF_CPP_MIN_LOG_LEVEL=0
# ----> 3 import optimize_decoder_matrix as odm
#       4
#       5 M_opt, debug = odm.stage_test(3)
#
# ModuleNotFoundError: No module named 'optimize_decoder_matrix'

# %%
import write_faust_decoder as wfd

print(wfd.matrix2faust(M_opt, prefix="s(%03d, 0) = "))
# Out:
# s(000, 0) = (+0.1709197 , +0.10607876, +0.04892115, +0.22617911, +0.16429045, +0.02425673, -0.14432439, +0.07409865, +0.13387202, +0.13637396, +0.0419669 , -0.04295556, -0.02205272, -0.10801807, +0.04939684, +0.03271024);
#
# s(001, 0) = (+0.16900311, -0.10544591, +0.05072038, +0.23430616, -0.1614672 , -0.02560383, -0.14391432, +0.06852624, +0.13393845, -0.13752584, -0.04673714, +0.04398353, -0.02190688, -0.1037172 , +0.05306337, +0.03556748);
#
# s(002, 0) = (+0.1655622 , +0.23801368, +0.06356214, +0.13725053, +0.19641729, +0.07712895, -0.12452079, +0.03598173, -0.12403002, -0.01641782, +0.07260543, -0.08339709, -0.04702592, -0.04863084, -0.03829688, -0.14814524);
#
# s(003, 0) = (+0.16612404, -0.23714596, +0.06292495, +0.12924766, -0.18944584, -0.07628687, -0.12615656, +0.03497024, -0.12602705, +0.02016126, -0.07378851, +0.08277493, -0.04172824, -0.04444039, -0.03975799, -0.14713514);
#
# s(004, 0) = (+0.15640381, +0.23054675, +0.06829811, -0.10746986, -0.1676707 , +0.08206547, -0.12567035, -0.03580944, -0.1460553 , -0.04253231, -0.06025317, -0.08441731, -0.04769869, +0.04471538, -0.04359737, +0.13031772);
#
# s(005, 0) = (+0.1618787 , -0.23467904, +0.06140008, -0.10857992, +0.17418245, -0.08079241, -0.12399734, -0.02780415, -0.14746677, +0.03868978, +0.05531951, +0.08498556, -0.04181031, +0.03910046, -0.04634398, +0.13656421);
#
# s(006, 0) = (+0.16564377, +0.10786973, +0.07466272, -0.22347351, -0.15502917, +0.02915273, -0.19692517, -0.09147905, +0.135079  , +0.1246229 , -0.0518951 , -0.06887508, +0.02546037, +0.13896428, +0.05365962, -0.03431278);
#
# s(007, 0) = (+0.20345115, -0.12467089, +0.04115763, -0.26591087, +0.17901162, -0.01823449, -0.18145402, -0.06611482, +0.15842538, -0.14321496, +0.04221092, +0.06828495, -0.00396718, +0.13685762, +0.04455951, -0.0408941 );
#
# s(008, 0) = (+0.14750785, +0.07505242, +0.11445787, +0.17645867, +0.09457517, +0.06861663, -0.01387787, +0.15396504, +0.09319224, +0.0461195 , +0.06758249, +0.01798733, -0.04759255, +0.03518036, +0.0659787 , +0.0155735 );
#
# s(009, 0) = (+0.14584569, -0.07413997, +0.11345851, +0.177217  , -0.09273276, -0.06779036, -0.01494063, +0.1532093 , +0.09402478, -0.04467051, -0.06702869, -0.01864701, -0.04758553, +0.03329671, +0.06794193, +0.01702308);
#
# s(010, 0) = (+0.40420604, +0.30014033, +0.51255877, +0.00501452, -0.00084118, +0.39007097, +0.33316269, +0.00738294, -0.10105396, -0.01278228, +0.00124111, +0.20471077, +0.10387941, +0.0062029 , -0.08579507, -0.00304512);
#
# s(011, 0) = (+0.40282825, -0.30133738, +0.51284984, +0.00456623, +0.00131043, -0.38987233, +0.33415717, +0.00665781, -0.103203  , +0.01274574, -0.00061798, -0.20291955, +0.10394169, +0.00470498, -0.08628209, -0.0014147 );
#
# s(012, 0) = (+0.1369123 , +0.06946302, +0.11160864, -0.16092867, -0.08136431, +0.06351815, -0.00247662, -0.14820772, +0.08368323, +0.03651546, -0.06129033, +0.01948492, -0.04175639, -0.04208374, +0.06233424, -0.0126198 );
#
# s(013, 0) = (+0.13921491, -0.06876771, +0.10889232, -0.16602614, +0.08050787, -0.06163578, -0.00755255, -0.14503499, +0.08773971, -0.03648446, +0.0590689 , -0.01748288, -0.04159023, -0.03698869, +0.06279121, -0.01586081);
#
# s(014, 0) = (+0.37316466, +0.00050716, +0.48740463, +0.21304932, -0.0009098 , -0.00532081, +0.35964122, +0.2672365 , +0.03912888, -0.00100349, +0.00065703, +0.00301405, +0.13878079, +0.14031795, +0.03287802, -0.00021895);
#
# s(015, 0) = (+0.3680421 , -0.00116352, +0.47929432, -0.21713103, -0.00034058, -0.00553736, +0.35215037, -0.27537984, +0.03886489, -0.00131293, -0.00041204, +0.0014898 , +0.13829765, -0.14588631, +0.0319777 , -0.00152038);
#
# s(016, 0) = (+0.22642714, +0.07126101, +0.07064613, +0.28721553, +0.10403987, +0.0026711 , -0.27117388, +0.15163383, +0.25469461, +0.09358565, +0.02253393, -0.02007151, +0.03691743, -0.25308377, +0.09403817, +0.15737803);
#
# s(017, 0) = (+0.16906354, -0.06394923, +0.04859429, +0.21779701, -0.10443116, -0.01473931, -0.18370766, +0.10059273, +0.17493717, -0.0884365 , -0.02419564, +0.02715464, +0.01448661, -0.17049499, +0.07076965, +0.10584498);
#
# s(018, 0) = (+0.21236145, +0.25106848, +0.03659747, +0.19477321, +0.26455727, +0.02828643, -0.2058194 , +0.05569394, -0.04093148, +0.08240203, +0.05463873, -0.11110312, +0.01464559, -0.14246808, +0.01661851, -0.11839941);
#
# s(019, 0) = (+0.2194427 , -0.25081295, +0.02402755, +0.19787432, -0.26351494, -0.03015947, -0.18585277, +0.04731871, -0.04120817, -0.07983453, -0.0551458 , +0.11359794, -0.01373591, -0.12539734, +0.01972263, -0.12013308);
#
# s(020, 0) = (+0.34254805, +0.49263394, +0.05106869, +0.10313408, +0.15070333, +0.08729403, -0.27269362, +0.01138867, -0.37404161, -0.18501801, +0.0426831 , -0.23192967, -0.02786556, -0.0271255 , -0.08983108, -0.11425401);
#
# s(021, 0) = (+0.35672262, -0.49058425, +0.03160247, +0.09894055, -0.15024352, -0.09190319, -0.25008974, +0.01056568, -0.38045582, +0.18845394, -0.04413282, +0.2211274 , -0.04907654, -0.02453245, -0.08919242, -0.11270331);
#
# s(022, 0) = (+0.21500771, +0.32732409, +0.07964682, -0.10618677, -0.16456528, +0.10823282, -0.16794397, -0.02968943, -0.255459  , -0.13924119, -0.04592125, -0.12534809, -0.05555282, +0.05238331, -0.07919832, +0.12613257);
#
# s(023, 0) = (+0.21525435, -0.32141081, +0.07302039, -0.10340659, +0.16351044, -0.11025131, -0.15890693, -0.02049871, -0.25513771, +0.13679131, +0.04121039, +0.11811569, -0.04958189, +0.03808604, -0.08353286, +0.12787648);
#
# s(024, 0) = (+0.22216147, +0.26880534, +0.07063251, -0.19382488, -0.27351164, +0.06249848, -0.24000235, -0.0818378 , -0.05104908, +0.07779167, -0.09126318, -0.14074414, +0.02074597, +0.1444231 , +0.00288011, +0.14164128);
#
# s(025, 0) = (+0.27236184, -0.28992746, +0.01721021, -0.23513407, +0.30730596, -0.05487034, -0.20419961, -0.04736122, -0.03429114, -0.09401994, +0.07395969, +0.14474671, -0.02855951, +0.12972144, -0.00951584, +0.1451495 );
#
# s(026, 0) = (+0.21203509, +0.05246785, +0.0844318 , -0.30233842, -0.08296625, +0.0223797 , -0.27483349, -0.12455729, +0.27103451, +0.07659688, -0.03510979, -0.04126071, +0.0634098 , +0.21945981, +0.07013517, -0.15130574);
#
# s(027, 0) = (+0.17325752, -0.07175038, +0.04542095, -0.24164051, +0.10357739, -0.00374123, -0.18259013, -0.07339242, +0.19374865, -0.09301284, +0.02395801, +0.02971215, +0.02281397, +0.15165563, +0.04857729, -0.1012151 );
#
# s(028, 0) = (+0.14326634, +0.05671773, +0.08532348, +0.1953358 , +0.08458462, +0.03711065, -0.06606146, +0.13246964, +0.13826613, +0.06672013, +0.05702842, +0.00049788, -0.06585247, -0.0130582 , +0.09066862, +0.05805507);
#
# s(029, 0) = (+0.15351898, -0.05666896, +0.09108257, +0.21605458, -0.08790192, -0.0382754 , -0.07313405, +0.14128621, +0.1520293 , -0.06874295, -0.05785401, -0.00105677, -0.07270843, -0.01858655, +0.10111102, +0.06627574);
#
# s(030, 0) = (+0.15609857, +0.13010452, +0.10062781, +0.19152427, +0.18254834, +0.09551479, -0.06016896, +0.12883923, +0.05520312, +0.08557896, +0.11676106, +0.0070403 , -0.07066886, -0.00325874, +0.03064348, -0.03607281);
#
# s(031, 0) = (+0.15375955, -0.13307593, +0.10295293, +0.19262438, -0.17718025, -0.09199234, -0.06409588, +0.12658181, +0.05470677, -0.0848415 , -0.11900397, -0.0052295 , -0.06910089, -0.00220593, +0.03348323, -0.03382482);
#
# s(032, 0) = (+0.22700147, +0.26311196, +0.17099822, +0.14557748, +0.18017771, +0.23201238, -0.02766432, +0.11704928, -0.1136446 , +0.00171553, +0.11936878, +0.05572124, -0.0756757 , +0.02478369, -0.07968359, -0.0733798 );
#
# s(033, 0) = (+0.22451595, -0.2645766 , +0.17292728, +0.14092296, -0.17531776, -0.23148812, -0.02849209, +0.1156711 , -0.11366032, +0.0012353 , -0.12064716, -0.0565157 , -0.07332481, +0.02954145, -0.08138077, -0.0742672 );
#
# s(034, 0) = (+0.20030848, +0.25899238, +0.16316785, -0.0100877 , -0.01295308, +0.24007332, -0.00792869, -0.00542501, -0.17541249, -0.05126627, -0.00848127, +0.07159842, -0.07042138, -0.00020218, -0.1284312 , +0.00296673);
#
# s(035, 0) = (+0.19613452, -0.25905138, +0.16645147, -0.00752844, +0.01188914, -0.24216259, -0.00433254, -0.00609674, -0.1765132 , +0.05329574, +0.00786081, -0.07588407, -0.06918602, -0.00049912, -0.13213102, +0.00305852);
#
# s(036, 0) = (+0.24802198, +0.2786837 , +0.18813719, -0.17103858, -0.21087096, +0.2470437 , -0.0330511 , -0.1414219 , -0.10435454, +0.0025958 , -0.14337701, +0.06228443, -0.08498768, -0.03187332, -0.07140083, +0.08152642);
#
# s(037, 0) = (+0.24594305, -0.28228031, +0.18791461, -0.16715621, +0.2080894 , -0.2456569 , -0.03325427, -0.13682239, -0.10541041, -0.00259706, +0.14064525, -0.06220115, -0.08333425, -0.03199581, -0.07446092, +0.08219914);
#
# s(038, 0) = (+0.13496994, +0.1065794 , +0.09559323, -0.16403218, -0.14559123, +0.07813912, -0.05107491, -0.12189542, +0.05736291, +0.07484825, -0.10159035, +0.00614747, -0.06189555, -0.00868701, +0.03874367, +0.01722223);
#
# s(039, 0) = (+0.14356955, -0.11084625, +0.09165488, -0.17490138, +0.15070809, -0.07649011, -0.05913652, -0.11653388, +0.06308601, -0.07772412, +0.09841942, -0.00083603, -0.06027215, -0.00272073, +0.03830048, +0.01368314);
#
# s(040, 0) = (+0.13736666, +0.05225997, +0.0912041 , -0.19608217, -0.07512544, +0.03497026, -0.05643488, -0.13394053, +0.1366207 , +0.05965036, -0.05627822, +0.00123812, -0.06633406, +0.00437378, +0.09477378, -0.05729453);
#
# s(041, 0) = (+0.15746346, -0.05323719, +0.09328295, -0.22555583, +0.08250901, -0.03464778, -0.06938323, -0.14016452, +0.15684244, -0.06515362, +0.05337246, +0.00295453, -0.07256413, +0.0129607 , +0.10421604, -0.06714061);
#
# s(042, 0) = (+0.24964697, +0.00354477, +0.2268231 , +0.29924637, +0.00000041, -0.0000887 , +0.02014753, +0.29887182, +0.20091615, +0.00213696, +0.00149826, -0.00160109, -0.06276077, +0.09895342, +0.14529313, +0.07021965);
#
# s(043, 0) = (+0.26995637, +0.16307224, +0.29694401, +0.23393169, +0.14318606, +0.19895524, +0.13265256, +0.26974617, +0.0442837 , +0.02617446, +0.10946194, +0.09503179, +0.0007223 , +0.12478244, +0.0309899 , -0.0061944 );
#
# s(044, 0) = (+0.26970407, -0.1596749 , +0.29403342, +0.23151823, -0.13935589, -0.19543024, +0.13124273, +0.2719163 , +0.04727364, -0.02414207, -0.10647752, -0.09267727, +0.00145866, +0.12578196, +0.03364572, -0.00471199);
#
# s(045, 0) = (+0.26642436, +0.15233174, +0.29135515, -0.23267235, -0.13077121, +0.17856632, +0.13279531, -0.27928537, +0.05651632, +0.02477799, -0.10145682, +0.08588822, +0.00228683, -0.13153872, +0.04059737, +0.00152892);
#
# s(046, 0) = (+0.26368889, -0.14928608, +0.28880453, -0.23128241, +0.12493051, -0.17546723, +0.13012617, -0.27608378, +0.05632436, -0.02378682, +0.09764633, -0.08427105, +0.00252095, -0.12818257, +0.04124127, -0.00027148);
#
# s(047, 0) = (+0.23092362, +0.00304075, +0.21045407, -0.2771625 , -0.00176028, +0.00138282, +0.03179341, -0.28039955, +0.18329537, +0.00146765, -0.0016763 , +0.00009213, -0.05414608, -0.09766284, +0.13386677, -0.05669121);
#
# s(048, 0) = (+0.15176029, +0.24691226, +0.10412877, +0.62381646, +0.27035648, -0.10721936, -0.36235006, -0.41404412, +0.24560432, +0.15821966, -0.06214269, -0.04277568, +0.16316483, +0.03330262, -0.09901164, +0.00911012);
#
# s(049, 0) = (+0.23766422, -0.23308193, -0.00567874, +0.64760662, -0.2852451 , +0.07057818, -0.27478963, -0.38713033, +0.29995593, -0.14866639, +0.08000384, +0.09792724, +0.06433494, -0.03778136, -0.14830213, +0.0166108 );
#
# s(050, 0) = (+0.27457465, +0.54880728, -0.22048263, +0.2778524 , +0.20994653, -0.41790742, +0.12276374, -0.25839174, -0.24938696, -0.0552046 , -0.07257809, +0.05948078, -0.266661  , +0.13123403, +0.11766306, -0.12917965);
#
# s(051, 0) = (+0.25710705, -0.57692989, -0.20924058, +0.29096237, -0.21113923, +0.43232234, +0.11667828, -0.25681173, -0.24753683, +0.05574854, +0.08252824, -0.08805912, -0.21697304, +0.09437052, +0.10940716, -0.11895865);
#
# s(052, 0) = (+0.12463186, +0.61747052, +0.04301287, -0.30537394, -0.2279949 , -0.45757303, -0.18495832, +0.28018409, -0.27388516, -0.05027825, +0.08828345, +0.09668619, +0.01024139, -0.11798708, +0.1080731 , +0.11626768);
#
# s(053, 0) = (+0.04296194, -0.59686771, +0.15665486, -0.26892998, +0.22937458, +0.44712532, -0.35604761, +0.2006739 , -0.25103436, +0.0336601 , -0.07977255, -0.07671321, +0.14408835, -0.01010926, +0.10886524, +0.12786848);
#
# s(054, 0) = (+0.22962217, +0.28370385, +0.01537588, -0.62630811, -0.26971225, -0.16959862, -0.28608615, +0.33516062, +0.31303649, +0.16681087, +0.05788431, +0.03584402, +0.09333373, +0.08804742, -0.17094659, -0.01599163);
#
# s(055, 0) = (+0.33160298, -0.24925741, -0.22321341, -0.60363085, +0.23373979, +0.17489427, +0.05905198, +0.38643806, +0.29075139, -0.16127252, -0.04907708, -0.06278222, -0.19760835, -0.03258511, -0.12949062, -0.03182602);
